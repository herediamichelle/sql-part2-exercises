-- %% [markdown]
-- # Exercises
--
-- To get started with the exercises, go ahead and take a look at RideShareDB. This database was created with data from a dataset on [Kaggle](https://www.kaggle.com/fivethirtyeight/uber-pickups-in-new-york-city). The dataset was made using data obtained from the NYC Taxi and Limosine Commission or TLC. TLC tracks this data by base and even rideshare companies such as Uber and Lyft have assigned bases that each pickup must be attributed to. For the exercises, we will be using the `other-FHV-services-jan-july15` and `lyft` tables in RideShareDB. These tables include the data for each pickup attributed to a few other For-Hire Vehicles (FHV) services and Lyft. These tables do not include any data from Uber.
--
-- ## String Functions
--
-- Write a query that returns the last 3 characters of the base name in `other-FHV-services-jan-july15`. Do you see anything that is a common abbreviation at the end of business names?

-- %%
select top 10 right(base_name,3) from ridesharedb.dbo.other_FHV_services_jan_aug_2015

-- yes, abbreviation
-- Out:
-- (10 rows affected)
-- Total execution time: 00:00:00.046
-- <table><tr><th>(No column name)</th></tr><tr><td>INC</td></tr><tr><td>INC</td></tr><tr><td>ORP</td></tr><tr><td>INC</td></tr><tr><td>NC.</td></tr><tr><td>INC</td></tr><tr><td>NC.</td></tr><tr><td>NC.</td></tr><tr><td>DIO</td></tr><tr><td>RP.</td></tr></table>

-- %% [markdown]
-- The number of trips and the number of pickups are both stored as strings in `other-FHV-services-jan-july15`. This is because the data provided included spaces in some of the numbers. Write a query that returns the location of spaces in both of these columns.

-- %%
SELECT CHARINDEX(Number_of_Trips, ' ')  as 'spacelocation trips' , charindex(Number_of_Vehicles, ' ') as 'spacelocation_vehicle' from RideShareDB.dbo.other_FHV_services_jan_aug_2015 
--SELECT CHARINDEX(Number_of_Vehicles, ' ')  as 'spacelocation vehicle'from RideShareDB.dbo.other_FHV_services_jan_aug_2015
-- Out:
-- (26181 rows affected)
-- Displaying Top 5000 rows.
-- Total execution time: 00:00:00.213
-- <table><tr><th>spacelocation trips</th><th>spacelocation_vehicle</th></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</td><td>0</td></tr><tr><td>0</ ...

-- %% [markdown]
-- ## Date Functions
--
-- For ``other-FHV-services-jan-july15``, display the name of month of the pickup date and order in descending order. Is the result of this query what you expected?

-- %%
SELECT top 5 MONTH(Pick_up_Date) as "Month" from RideShareDB.dbo.other_FHV_services_jan_aug_2015 ORDER by Pick_Up_Date DESC
-- no, it looks like it shows august data instead of just jan-july
-- Out:
-- (5 rows affected)
-- Total execution time: 00:00:00.047
-- <table><tr><th>Month</th></tr><tr><td>8</td></tr><tr><td>8</td></tr><tr><td>8</td></tr><tr><td>8</td></tr><tr><td>8</td></tr></table>

-- %% [markdown]
-- Using `other-FHV-services-jan-july15`, write a query that returns the day number of the pickup date and month name and orders it in ascending order by day number.

-- %%
select top 100 day(Pick_Up_Date) as 'Day', month(Pick_Up_Date) as "Month" from RideShareDB.dbo.other_FHV_services_jan_aug_2015 order by DAY ASC
-- Out:
-- (100 rows affected)
-- Total execution time: 00:00:00.059
-- <table><tr><th>Day</th><th>Month</th></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>2</td></tr></table>

-- %% [markdown]
-- ## Aggregate Functions
--
-- Write a query that returns the most easterly Lyft pickup.

-- %%
--SELECT * from RideShareDB.dbo.lyft

-- should be the minium value for most easterly
SELECT Min(start_lat) from RideShareDB.dbo.lyft
-- Out:
-- Warning: Null value is eliminated by an aggregate or other SET operation.
-- (1 row affected)
-- Total execution time: 00:00:00.086
-- <table><tr><th>(No column name)</th></tr><tr><td>40.93562</td></tr></table>

-- %% [markdown]
-- Write a query the returns the most northerly Lyft pickup.

-- %%
-- should be maximum for most notherly
select max(start_lng) from RideShareDB.dbo.lyft
-- Out:
-- Warning: Null value is eliminated by an aggregate or other SET operation.
-- (1 row affected)
-- Total execution time: 00:00:00.086
-- <table><tr><th>(No column name)</th></tr><tr><td>-73.72315</td></tr></table>

-- %% [markdown]
-- Using ``other-FHV-services-jan-july15``, write a query that connects the the base number and the base name in a string that uses the following format: base\_number: base\_name.

-- %%
Select top 10 Base_Number, Base_Name, 
    isNull(Base_number, 'n/a') + ' : ' + isnull(Base_Name, 'n/a') as "Combined"
from RideShareDB.dbo.other_FHV_services_jan_aug_2015
-- Out:
-- (10 rows affected)
-- Total execution time: 00:00:00.039
-- <table><tr><th>Base_Number</th><th>Base_Name</th><th>Combined</th></tr><tr><td>B00013</td><td>LOVE CORP CAR INC</td><td>B00013 : LOVE CORP CAR INC</td></tr><tr><td>B00014</td><td>NY ONE CORP CAR INC</td><td>B00014 : NY ONE CORP CAR INC</td></tr><tr><td>B00029</td><td>COMMUNITY CAR SVC CORP</td><td>B00029 : COMMUNITY CAR SVC CORP</td></tr><tr><td>B00053</td><td>CHARGE AND RIDE INC</td><td>B00053 : CHARGE AND RIDE INC</td></tr><tr><td>B00095</td><td>LIBERTY CAR SERVICE INC.</td><td>B00095 : LIBERTY CAR SERVICE INC.</td></tr><tr><td>B00221</td><td>PROFESSIONAL CAR SERVICE INC</td><td>B00221 : PROFESSIONAL CAR SERVICE INC</td></tr><tr><td>B00227</td><td>PARK WEST EXEC. SERVICES, INC.</td><td>B00227 : PARK WEST EXEC. SERVICES, INC.</td></tr><tr><td>B00248</td><td>YELLOWSTONE TRANSPORTATION INC.</td><td>B00248 : YELLOWSTONE TRANSPORTATION INC.</td></tr><tr><td>B00254</td><td>XYZ TWO WAY RADIO</td><td>B00254 : XYZ TWO WAY RADIO</td></tr><tr><td>B00280</td><td>FLEET RADIO DISPATCH CORP.</td><td>B00280 : FLEET RADIO DISPATCH CORP.</td></tr></table>
